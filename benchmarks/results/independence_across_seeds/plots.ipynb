# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # p-values of the chi-squared test for independence

# %%
df = pd.read_json("64_bytes_2_seeds_to_range_to_incl_17", orient="records", lines=True)
px.line(df, x="num keys", y="p-value", color="algo")
