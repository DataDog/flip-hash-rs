# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # L2 distance from the uniform distribution

# %%
df = pd.read_json("64_bytes_to_range_to_incl_99", orient="records", lines=True)
px.line(df, x="num keys", y="l2 distance", color="algo", log_x=True, log_y=True)

# %% [markdown]
# # p-values of the Chi-Squared test for uniformity

# %%
px.line(df, x="num keys", y="p-value", color="algo")
